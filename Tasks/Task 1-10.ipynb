# %% [markdown]
# # Task 1-10

# %%
# Sum two numbers (3)
num1=3
num2=7
sum=num1+num2

print("Your result is: ",sum)
# Out:
# Your result is:  10

# %%
# Get data from user than Sum (4)
num1=float(input("Enter first number= "))
num2=float(input("Enter second number= "))
sum=num1+num2

print("Your result is: ",sum)
# Out:
# Enter first number=  5
# Enter second number=  4
# Your result is:  9.0

# %%
#Calculate the square root of a number (5)
num=float(input("Enter number= "))
nsrq=num**0.5
print("The square of",num ,"is" , round(nsrq,2))
# Out:
# Enter number=  8
# The square of 8.0 is 2.83

# %%
#Calculate the square root of a number by import cmaths (6)

import math
num=float(input("Enter number= "))
print("Your result is= ",round(math.sqrt(num),3))
# Out:
# Enter number=  8
# Your result is=  2.828

# %%
#Convert Celsius to fahrenheit (7)

c = float(input("Enter Temperature in Celsius = "))
f = 9/5 * c + 32
print("Temperature in Fahrenheit =", round(f,3))
# Out:
# Enter Temperature in Celsius =  37
# Temperature in Fahrenheit = 98.6

# %%
# Area of triangle (8)

a=float(input("Enter value of a = "))
b=float(input("Enter value of b = "))
c=float(input("Enter value of c = "))

s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**0.5

print("Area of triangle = ",area)
# Out:
# Enter value of a =  5
# Enter value of b =  6
# Enter value of c =  3
# Area of triangle =  7.483314773547883

# %%
# Quadic Formula (pending) (9)

# %%
#convert meter to kilometer (10)

m=float(input("Enter length in meter= "))
km= m / 1000
print(m,"meters = ",km, "km")
# Out:
# Enter length in meter=  1500
# 1500.0 meters =  1.5 km
